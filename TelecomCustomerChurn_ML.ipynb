# %%
import pandas as pd
cust=pd.read_csv('telecom_customer_churn.csv')

# %%
cust.head(2)
# Out:
#   Customer ID  Gender  Age Married  Number of Dependents          City  \
# 0  0002-ORFBO  Female   37     Yes                     0  Frazier Park
# 1  0003-MKNFE    Male   46      No                     0      Glendale
#
#    Zip Code   Latitude   Longitude  Number of Referrals  ...  Payment Method  \
# 0     93225  34.827662 -118.999073                    2  ...     Credit Card
# 1     91206  34.162515 -118.203869                    0  ...     Credit Card
#
#   Monthly Charge Total Charges  Total Refunds Total Extra Data Charges  \
# 0           65.6         593.3           0.00                        0
# 1           -4.0         542.4          38.33                       10
#
#   Total Long Distance Charges Total Revenue  Customer Status Churn Category  \
# 0                      381.51        974.81           Stayed            NaN
# 1                       96.21        610.28           Stayed            NaN
#
#   Churn Reason
# 0          NaN
# 1          NaN
#
# ...

# %%
cust=cust.drop(['Zip Code','Latitude','Longitude','City'], axis=1) #Removing geo data

# %%
cust.head(2)
# Out:
#   Customer ID  Gender  Age Married  Number of Dependents  Number of Referrals  \
# 0  0002-ORFBO  Female   37     Yes                     0                    2
# 1  0003-MKNFE    Male   46      No                     0                    0
#
#    Tenure in Months Offer Phone Service  Avg Monthly Long Distance Charges  \
# 0                 9  None           Yes                              42.39
# 1                 9  None           Yes                              10.69
#
#    ... Payment Method Monthly Charge Total Charges  Total Refunds  \
# 0  ...    Credit Card           65.6         593.3           0.00
# 1  ...    Credit Card           -4.0         542.4          38.33
#
#   Total Extra Data Charges Total Long Distance Charges Total Revenue  \
# 0                        0                      381.51        974.81
# 1                       10                       96.21        610.28
#
#   Customer Status Churn Category Churn Reason
# ...

# %%
cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 34 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Customer ID                        7043 non-null   object
#  1   Gender                             7043 non-null   object
#  2   Age                                7043 non-null   int64
#  3   Married                            7043 non-null   object
#  4   Number of Dependents               7043 non-null   int64
#  5   Number of Referrals                7043 non-null   int64
#  6   Tenure in Months                   7043 non-null   int64
#  7   Offer                              7043 non-null   object
#  8   Phone Service                      7043 non-null   object
#  9   Avg Monthly Long Distance Charges  6361 non-null   float64
#  10  Multiple Lines                     6361 non-null   object
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))
sns.heatmap(cust.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
cust=cust.drop(['Churn Category','Churn Reason'], axis=1)

# %%
#plt.figure(figsize=(8,5))
sns.heatmap(cust.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
cust[['Avg Monthly Long Distance Charges','Multiple Lines','Internet Type','Avg Monthly GB Download','Online Security', 'Online Backup',
      'Device Protection Plan', 'Premium Tech Support','Streaming Movies','Streaming Music','Unlimited Data']].head(10)
# Out:
#    Avg Monthly Long Distance Charges Multiple Lines Internet Type  \
# 0                              42.39             No         Cable
# 1                              10.69            Yes         Cable
# 2                              33.65             No   Fiber Optic
# 3                              27.82             No   Fiber Optic
# 4                               7.38             No   Fiber Optic
# 5                              16.77             No         Cable
# 6                               9.96             No   Fiber Optic
# 7                              12.96            Yes   Fiber Optic
# 8                              10.53             No           DSL
# 9                              28.46            Yes         Cable
#
#    Avg Monthly GB Download Online Security Online Backup  \
# 0                     16.0              No           Yes
# 1                     10.0              No            No
# 2                     30.0              No            No
# ...

# %%
cust['Avg Monthly Long Distance Charges']=cust['Avg Monthly Long Distance Charges'].fillna(0)

# %%
cust['Avg Monthly GB Download']=cust['Avg Monthly GB Download'].fillna(0)

# %%
plt.figure(figsize=(8,5))
sns.heatmap(cust.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
cust.isna().sum()
# Out:
# Customer ID                             0
# Gender                                  0
# Age                                     0
# Married                                 0
# Number of Dependents                    0
# Number of Referrals                     0
# Tenure in Months                        0
# Offer                                   0
# Phone Service                           0
# Avg Monthly Long Distance Charges       0
# Multiple Lines                        682
# Internet Service                        0
# Internet Type                        1526
# Avg Monthly GB Download                 0
# Online Security                      1526
# Online Backup                        1526
# Device Protection Plan               1526
# Premium Tech Support                 1526
# Streaming TV                         1526
# Streaming Movies                     1526
# Streaming Music                      1526
# Unlimited Data                       1526
# ...

# %%
cust['Internet Type'].unique()
# Out:
# array(['Cable', 'Fiber Optic', 'DSL', nan], dtype=object)

# %% [markdown]
# # One Hot Encoding

# %%
cust['Internet Type'].unique()
# Out:
# array(['Cable', 'Fiber Optic', 'DSL', nan], dtype=object)

# %%
from sklearn.preprocessing import OneHotEncoder
ohe=OneHotEncoder()

# %%
cust_1=pd.get_dummies(cust, columns = ['Internet Type'])

# %%
cust_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 34 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Customer ID                        7043 non-null   object
#  1   Gender                             7043 non-null   object
#  2   Age                                7043 non-null   int64
#  3   Married                            7043 non-null   object
#  4   Number of Dependents               7043 non-null   int64
#  5   Number of Referrals                7043 non-null   int64
#  6   Tenure in Months                   7043 non-null   int64
#  7   Offer                              7043 non-null   object
#  8   Phone Service                      7043 non-null   object
#  9   Avg Monthly Long Distance Charges  7043 non-null   float64
#  10  Multiple Lines                     6361 non-null   object
# ...

# %%
#cust_1[['Internet Type_Cable','Internet Type_DSL','Internet Type_Fiber Optic']]

# %%
Gender_dummie = pd.get_dummies(cust_1.Gender,prefix='Gender',drop_first=True)

# %%
Married_dummie = pd.get_dummies(cust_1.Married,prefix='Married',drop_first=True)

# %%
Phone_Service_dummie = pd.get_dummies(cust_1['Phone Service'] ,prefix='Phone Service',drop_first=True)

# %%
MultipleLines_dummie = pd.get_dummies(cust_1['Multiple Lines'] ,prefix='Multiple Lines',drop_first=True)

# %%
InternetService_dummie = pd.get_dummies(cust_1['Internet Service'] ,prefix='Internet Service',drop_first=True)

# %%
OnlineSecurity_dummie = pd.get_dummies(cust_1['Online Security'] ,prefix='Online Security',drop_first=True)

# %%
OnlineBackup_dummie = pd.get_dummies(cust_1['Online Backup'] ,prefix='Online Backup',drop_first=True)

# %%
DeviceProtectionPlan_dummie = pd.get_dummies(cust_1['Device Protection Plan'] ,prefix='Device Protection Plan',drop_first=True)

# %%
##################
PremiumTechSupport_dummie = pd.get_dummies(cust_1['Premium Tech Support'] ,prefix='Premium Tech Support',drop_first=True)
StreamingTV_dummie = pd.get_dummies(cust_1['Streaming TV'] ,prefix='Streaming TV',drop_first=True)
StreamingMovies_dummie = pd.get_dummies(cust_1['Streaming Movies'] ,prefix='Streaming Movies',drop_first=True)
StreamingMusic_dummie = pd.get_dummies(cust_1['Streaming Music'] ,prefix='Streaming Music',drop_first=True)
UnlimitedData_dummie = pd.get_dummies(cust_1['Unlimited Data'] ,prefix='Unlimited Data',drop_first=True)
PaperlessBilling_dummie = pd.get_dummies(cust_1['Paperless Billing'] ,prefix='Paperless Billing',drop_first=True)

# %%
dummie_data = pd.concat([Gender_dummie,Married_dummie,Phone_Service_dummie,MultipleLines_dummie,InternetService_dummie,OnlineSecurity_dummie,OnlineBackup_dummie,OnlineBackup_dummie,DeviceProtectionPlan_dummie
                         ,PremiumTechSupport_dummie,StreamingTV_dummie,StreamingMovies_dummie,StreamingMusic_dummie,UnlimitedData_dummie,PaperlessBilling_dummie],axis=1)

# %%
['Gender','Married','Phone Service','Multiple Lines','Internet Service','Online Security','Online Backup','Device Protection Plan','Premium Tech Support','Streaming TV','Streaming Movies','Streaming Music','Unlimited Data','Paperless Billing']
# Out:
# ['Gender',
#  'Married',
#  'Phone Service',
#  'Multiple Lines',
#  'Internet Service',
#  'Online Security',
#  'Online Backup',
#  'Device Protection Plan',
#  'Premium Tech Support',
#  'Streaming TV',
#  'Streaming Movies',
#  'Streaming Music',
#  'Unlimited Data',
#  'Paperless Billing']

# %%
dummie_data.head()
# Out:
#    Gender_Male  Married_Yes  Phone Service_Yes  Multiple Lines_Yes  \
# 0            0            1                  1                   0
# 1            1            0                  1                   1
# 2            1            0                  1                   0
# 3            1            1                  1                   0
# 4            0            1                  1                   0
#
#    Internet Service_Yes  Online Security_Yes  Online Backup_Yes  \
# 0                     1                    0                  1
# 1                     1                    0                  0
# 2                     1                    0                  0
# 3                     1                    0                  1
# 4                     1                    0                  0
#
#    Online Backup_Yes  Device Protection Plan_Yes  Premium Tech Support_Yes  \
# 0                  1                           0                         1
# ...

# %%
cust_1.drop('Offer', axis=1, inplace=True) #Dropping offer as majority people do not take any offers

# %%
cust_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Customer ID                        7043 non-null   object
#  1   Gender                             7043 non-null   object
#  2   Age                                7043 non-null   int64
#  3   Married                            7043 non-null   object
#  4   Number of Dependents               7043 non-null   int64
#  5   Number of Referrals                7043 non-null   int64
#  6   Tenure in Months                   7043 non-null   int64
#  7   Phone Service                      7043 non-null   object
#  8   Avg Monthly Long Distance Charges  7043 non-null   float64
#  9   Multiple Lines                     6361 non-null   object
#  10  Internet Service                   7043 non-null   object
# ...

# %%
cust_2=pd.get_dummies(cust_1, columns = ['Contract','Payment Method'])

# %%
cust_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 37 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Customer ID                        7043 non-null   object
#  1   Gender                             7043 non-null   object
#  2   Age                                7043 non-null   int64
#  3   Married                            7043 non-null   object
#  4   Number of Dependents               7043 non-null   int64
#  5   Number of Referrals                7043 non-null   int64
#  6   Tenure in Months                   7043 non-null   int64
#  7   Phone Service                      7043 non-null   object
#  8   Avg Monthly Long Distance Charges  7043 non-null   float64
#  9   Multiple Lines                     6361 non-null   object
#  10  Internet Service                   7043 non-null   object
# ...

# %%
#Concatinate dummie data to cust_2 and remove old cols

# %%
cust_2.drop(['Gender','Married','Phone Service','Multiple Lines','Internet Service','Online Security','Online Backup','Device Protection Plan','Premium Tech Support','Streaming TV','Streaming Movies',
              'Streaming Music','Unlimited Data','Paperless Billing'],axis=1,inplace=True)

# %%
cust_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Customer ID                        7043 non-null   object
#  1   Age                                7043 non-null   int64
#  2   Number of Dependents               7043 non-null   int64
#  3   Number of Referrals                7043 non-null   int64
#  4   Tenure in Months                   7043 non-null   int64
#  5   Avg Monthly Long Distance Charges  7043 non-null   float64
#  6   Avg Monthly GB Download            7043 non-null   float64
#  7   Monthly Charge                     7043 non-null   float64
#  8   Total Charges                      7043 non-null   float64
#  9   Total Refunds                      7043 non-null   float64
#  10  Total Extra Data Charges           7043 non-null   int64
# ...

# %%
cust_3=pd.concat([cust_2,dummie_data],axis=1)

# %%
cust_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 38 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Customer ID                        7043 non-null   object
#  1   Age                                7043 non-null   int64
#  2   Number of Dependents               7043 non-null   int64
#  3   Number of Referrals                7043 non-null   int64
#  4   Tenure in Months                   7043 non-null   int64
#  5   Avg Monthly Long Distance Charges  7043 non-null   float64
#  6   Avg Monthly GB Download            7043 non-null   float64
#  7   Monthly Charge                     7043 non-null   float64
#  8   Total Charges                      7043 non-null   float64
#  9   Total Refunds                      7043 non-null   float64
#  10  Total Extra Data Charges           7043 non-null   int64
# ...

# %%
cust_4=cust_3[cust_3['Customer Status']!='Joined'] #removing all data where customer status=joined

# %%
CustomerStatus_dummie = pd.get_dummies(cust_4['Customer Status'] ,prefix='Customer Status',drop_first=True)

# %%
cust_4.drop(['Customer Status'], axis=1,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
cust_5=pd.concat([cust_4,CustomerStatus_dummie], axis=1,)

# %%
cust_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6589 entries, 0 to 7042
# Data columns (total 38 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Customer ID                        6589 non-null   object
#  1   Age                                6589 non-null   int64
#  2   Number of Dependents               6589 non-null   int64
#  3   Number of Referrals                6589 non-null   int64
#  4   Tenure in Months                   6589 non-null   int64
#  5   Avg Monthly Long Distance Charges  6589 non-null   float64
#  6   Avg Monthly GB Download            6589 non-null   float64
#  7   Monthly Charge                     6589 non-null   float64
#  8   Total Charges                      6589 non-null   float64
#  9   Total Refunds                      6589 non-null   float64
#  10  Total Extra Data Charges           6589 non-null   int64
# ...

# %% [markdown]
# # Logistic Regression

# %%
x=cust_5.drop(['Customer Status_Stayed'], axis=1)

# %%
y=cust_5['Customer Status_Stayed']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, 
                                                    y, test_size=0.30, 
                                                    random_state=101)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
predictions = logmodel.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predictions)) #When hasing was used for cust ID
# Out:
#               precision    recall  f1-score   support
#
#            0       0.28      0.47      0.35       573
#            1       0.70      0.51      0.59      1404
#
#     accuracy                           0.50      1977
#    macro avg       0.49      0.49      0.47      1977
# weighted avg       0.58      0.50      0.52      1977

# %%
#Need to convert ID to int

# %%
cust_5['Customer ID']=cust_5['Customer ID'].apply(lambda x:hash(x))

# %%
cust_6=cust_5.copy()

# %%
cust_6['Customer ID'] = range(1, len(cust_6) + 1)

# %%
cust_6.head(2)

# %%
x=cust_6.drop(['Customer Status_Stayed'], axis=1)
y=cust_6['Customer Status_Stayed']
X_train, X_test, y_train, y_test = train_test_split(x, 
                                                    y, test_size=0.30, 
                                                    random_state=101)

# %%
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
predictions = logmodel.predict(X_test)

# %%
print(classification_report(y_test,predictions)) #When indexing was used for cust ID
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.62      0.66       573
#            1       0.85      0.89      0.87      1404
#
#     accuracy                           0.81      1977
#    macro avg       0.78      0.76      0.77      1977
# weighted avg       0.81      0.81      0.81      1977

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=1)

from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
# making predictions on the testing set
y_pred = gnb.predict(X_test)

# %%
from sklearn import metrics
print("Gaussian Naive Bayes model accuracy(in %):", metrics.accuracy_score(y_test, y_pred)*100)
# Out:
# Gaussian Naive Bayes model accuracy(in %): 80.95599393019727

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.83      0.71       734
#            1       0.92      0.80      0.86      1902
#
#     accuracy                           0.81      2636
#    macro avg       0.77      0.82      0.78      2636
# weighted avg       0.84      0.81      0.82      2636

# %% [markdown]
# # 81% prediction accuracy
