# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
zipcode = pd.read_csv('telecom_zipcode_population.csv',encoding='cp1252')
dic=pd.read_csv('telecom_data_dictionary.csv',encoding='cp1252')
cust=pd.read_csv('telecom_customer_churn.csv',encoding='cp1252')

# %%
zipcode.head()
# Out:
#    Zip Code  Population
# 0     90001       54492
# 1     90002       44586
# 2     90003       58198
# 3     90004       67852
# 4     90005       43019

# %%
dic_chirnTable=dic[dic['Table']=='Customer Churn']

# %%
for i in range(0,38):
    print(f'index:{i} '+dic_chirnTable.iloc[i][2])
# Out:
# index:0 A unique ID that identifies each customer
# index:1 The customer’s gender: Male, Female
# index:2 The customer’s current age, in years, at the time the fiscal quarter ended (Q2 2022)
# index:3 Indicates if the customer is married: Yes, No
# index:4 Indicates the number of dependents that live with the customer (dependents could be children, parents, grandparents, etc.)
# index:5 The city of the customer’s primary residence in California
# index:6 The zip code of the customer’s primary residence
# index:7 The latitude of the customer’s primary residence
# index:8 The longitude of the customer’s primary residence
# index:9 Indicates the number of times the customer has referred a friend or family member to this company to date
# index:10 Indicates the total amount of months that the customer has been with the company by the end of the quarter specified above
# ...

# %%
dic_chirnTable
# Out:
#              Table                              Field  \
# 0   Customer Churn                         CustomerID
# 1   Customer Churn                             Gender
# 2   Customer Churn                                Age
# 3   Customer Churn                            Married
# 4   Customer Churn               Number of Dependents
# 5   Customer Churn                               City
# 6   Customer Churn                           Zip Code
# 7   Customer Churn                           Latitude
# 8   Customer Churn                          Longitude
# 9   Customer Churn                Number of Referrals
# 10  Customer Churn                   Tenure in Months
# 11  Customer Churn                              Offer
# 12  Customer Churn                      Phone Service
# 13  Customer Churn  Avg Monthly Long Distance Charges
# 14  Customer Churn                     Multiple Lines
# 15  Customer Churn                   Internet Service
# ...

# %%
cust.head()
# Out:
#   Customer ID  Gender  Age Married  Number of Dependents          City  \
# 0  0002-ORFBO  Female   37     Yes                     0  Frazier Park
# 1  0003-MKNFE    Male   46      No                     0      Glendale
# 2  0004-TLHLJ    Male   50      No                     0    Costa Mesa
# 3  0011-IGKFF    Male   78     Yes                     0      Martinez
# 4  0013-EXCHZ  Female   75     Yes                     0     Camarillo
#
#    Zip Code   Latitude   Longitude  Number of Referrals  ...   Payment Method  \
# 0     93225  34.827662 -118.999073                    2  ...      Credit Card
# 1     91206  34.162515 -118.203869                    0  ...      Credit Card
# 2     92627  33.645672 -117.922613                    0  ...  Bank Withdrawal
# 3     94553  38.014457 -122.115432                    1  ...  Bank Withdrawal
# 4     93010  34.227846 -119.079903                    3  ...      Credit Card
#
# ...

# %%
type(cust[['Churn Reason','Customer Status']].iloc[1][0])
# Out:
# float

# %%
plt.figure(figsize=(8,6))
sns.heatmap(cust.corr(), linecolor='white', cmap='coolwarm', linewidths=0.2)
# Out:
# <AxesSubplot:>

# %%
cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 38 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Customer ID                        7043 non-null   object
#  1   Gender                             7043 non-null   object
#  2   Age                                7043 non-null   int64
#  3   Married                            7043 non-null   object
#  4   Number of Dependents               7043 non-null   int64
#  5   City                               7043 non-null   object
#  6   Zip Code                           7043 non-null   int64
#  7   Latitude                           7043 non-null   float64
#  8   Longitude                          7043 non-null   float64
#  9   Number of Referrals                7043 non-null   int64
#  10  Tenure in Months                   7043 non-null   int64
# ...

# %%
sns.countplot(x='Customer Status',hue='Premium Tech Support', data=cust)
# Out:
# <AxesSubplot:xlabel='Customer Status', ylabel='count'>

# %%
sns.countplot(x='Customer Status',hue='Streaming TV', data=cust)
# Out:
# <AxesSubplot:xlabel='Customer Status', ylabel='count'>

# %%
sns.barplot(x='Customer Status',y='Total Charges', data=cust)
# Out:
# <AxesSubplot:xlabel='Customer Status', ylabel='Total Charges'>

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Customer Status',y='Tenure in Months', data=cust)
#This is Avg Tenure in months by cust status
# Out:
# <AxesSubplot:xlabel='Customer Status', ylabel='Tenure in Months'>

# %%
sns.countplot(x='Customer Status',hue='Gender', data=cust)
# Out:
# <AxesSubplot:xlabel='Customer Status', ylabel='count'>

# %%
sns.displot(cust['Total Charges'], bins=20, kde=False)
#Most people's total charge is below 4000

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x="Customer Status", y="Total Charges", data=cust,palette='rainbow')
#Lot of outliers in churned section
# Out:
# <AxesSubplot:xlabel='Customer Status', ylabel='Total Charges'>

# %%
cust.describe().drop(['Zip Code','Latitude','Longitude'], axis=1)
# Out:
#                Age  Number of Dependents  Number of Referrals  \
# count  7043.000000           7043.000000          7043.000000
# mean     46.509726              0.468692             1.951867
# std      16.750352              0.962802             3.001199
# min      19.000000              0.000000             0.000000
# 25%      32.000000              0.000000             0.000000
# 50%      46.000000              0.000000             0.000000
# 75%      60.000000              0.000000             3.000000
# max      80.000000              9.000000            11.000000
#
#        Tenure in Months  Avg Monthly Long Distance Charges  \
# count       7043.000000                        6361.000000
# mean          32.386767                          25.420517
# std           24.542061                          14.200374
# min            1.000000                           1.010000
# 25%            9.000000                          13.050000
# ...

# %%
cust['Customer Status'].unique()
# Out:
# array(['Stayed', 'Churned', 'Joined'], dtype=object)

# %%
cust_joined=len(cust[cust['Customer Status']=='Joined'])

# %%
cust_in_beginng=cust['Customer Status'].count()

# %%
cust_churned=len(cust[cust['Customer Status']=='Churned'])

# %%
cust_churn_rate=(cust_churned/(cust_in_beginng-cust_joined))*100

# %%
cust_churn_rate #Customer churned at the end of Q2 2022, without considering newly joined
# Out:
# 28.36545758081651

# %%
cust[['Customer Status','Churn Category','Churn Reason']]
# Out:
#      Customer Status   Churn Category                   Churn Reason
# 0             Stayed              NaN                            NaN
# 1             Stayed              NaN                            NaN
# 2            Churned       Competitor  Competitor had better devices
# 3            Churned  Dissatisfaction        Product dissatisfaction
# 4            Churned  Dissatisfaction            Network reliability
# ...              ...              ...                            ...
# 7038          Stayed              NaN                            NaN
# 7039         Churned  Dissatisfaction        Product dissatisfaction
# 7040          Joined              NaN                            NaN
# 7041          Stayed              NaN                            NaN
# 7042          Stayed              NaN                            NaN
#
# [7043 rows x 3 columns]

# %%
cust['Churn Category'].unique()
# Out:
# array([nan, 'Competitor', 'Dissatisfaction', 'Other', 'Price', 'Attitude'],
#       dtype=object)

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Churn Category',data=cust)
#A lot of people are levaing because of competitor, we should do some market analysis
# Out:
# <AxesSubplot:xlabel='Churn Category', ylabel='count'>

# %%
ChurnReason_comp= cust[cust['Churn Category']=='Competitor']

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='Churn Reason',data=ChurnReason_comp)
#So we see the competitor has better devices and offers!
# Out:
# <AxesSubplot:xlabel='Churn Reason', ylabel='count'>

# %%
sns.catplot(x='Churn Category', hue='Churn Reason', data=cust, kind='count', height=6,aspect=2, palette='Set3')
#Reason for churn- comp better devices, better offers and attitude of support person

# %%
#Age of people churning out to comp? This seems all over the place- no specific pattern.
#How was their offer behavior? Most people are not taking up any offers. Offer A is better priced for inc in avg revenue.
#impact on revenue because of churn? Revenue dist graph in Power BI.
#What is making people stay?

# %%
churn_comp_or_att= cust[(cust['Churn Category']=='Competitor') | (cust['Churn Category']=='Attitude')]

# %%
churn_comp_or_att.head(2)
# Out:
#    Customer ID Gender  Age Married  Number of Dependents         City  \
# 2   0004-TLHLJ   Male   50      No                     0   Costa Mesa
# 19  0023-HGHWL   Male   67      No                     0  Morgan Hill
#
#     Zip Code   Latitude   Longitude  Number of Referrals  ...  \
# 2      92627  33.645672 -117.922613                    0  ...
# 19     95037  37.161544 -121.649371                    0  ...
#
#      Payment Method Monthly Charge Total Charges  Total Refunds  \
# 2   Bank Withdrawal           73.9        280.85            0.0
# 19  Bank Withdrawal           25.1         25.10            0.0
#
#    Total Extra Data Charges Total Long Distance Charges Total Revenue  \
# 2                         0                       134.6        415.45
# 19                        0                         0.0         25.10
#
#     Customer Status Churn Category                   Churn Reason
# 2           Churned     Competitor  Competitor had better devices
# ...

# %%
churn_comp_or_att.describe() #Avg age of people churning out is 50yrs
# Out:
#                Age  Number of Dependents      Zip Code     Latitude  \
# count  1155.000000           1155.000000   1155.000000  1155.000000
# mean     49.911688              0.107359  93363.763636    35.788025
# std      17.787524              0.541747   1728.412564     2.499131
# min      19.000000              0.000000  90001.000000    32.555828
# 25%      34.000000              0.000000  92117.000000    33.747112
# 50%      51.000000              0.000000  93205.000000    34.624399
# 75%      65.000000              0.000000  95057.000000    37.909808
# max      80.000000              7.000000  96148.000000    41.962127
#
#          Longitude  Number of Referrals  Tenure in Months  \
# count  1155.000000          1155.000000       1155.000000
# mean   -119.494925             0.490909         17.637229
# std       2.191759             1.035193         19.583422
# min    -124.240051             0.000000          1.000000
# 25%    -121.601872             0.000000          2.000000
# ...

# %%
sns.distplot(churn_comp_or_att['Age'])
# Out:
# C:\Users\LP556KF\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>
